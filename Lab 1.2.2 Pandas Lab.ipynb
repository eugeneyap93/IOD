# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))
# Out:
#      <input type="file" id="files-8755434b-ce4c-4640-9f9d-e58f5a7fa7c5" name="files[]" multiple disabled />
#      <output id="result-8755434b-ce4c-4640-9f9d-e58f5a7fa7c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Employee-attrition.csv to Employee-attrition.csv

# %%
df = pd.read_csv("Employee-attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
data
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A: 
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
# A:
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A: Job_Title is not available in DF
df['JobRole'].values
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        ..., 'Manufacturing Director', 'Sales Executive',
#        'Laboratory Technician'], dtype=object)

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A: 
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
def row_count(column_name):
    number_of_rows = len(df[column_name])
    return number_of_rows

# %%
def row_count1(column_name):
    number_of_rows = df[column_name].count()
    return number_of_rows

# %%
row_count('JobRole')
# Out:
# 1470

# %%
row_count1('JobRole')
# Out:
# 1470

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A:
df['Age'].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:
df.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
#Replace index with employee number 
df.set_index('EmployeeNumber' , inplace = True)

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:
df.iloc[0]
# Out:
# Age                                      41
# Attrition                               Yes
# BusinessTravel                Travel_Rarely
# DailyRate                              1102
# Department                            Sales
# DistanceFromHome                          1
# Education                                 2
# EducationField                Life Sciences
# EmployeeCount                             1
# EnvironmentSatisfaction                   2
# Gender                               Female
# HourlyRate                               94
# JobInvolvement                            3
# JobLevel                                  2
# JobRole                     Sales Executive
# JobSatisfaction                           4
# MaritalStatus                        Single
# MonthlyIncome                          5993
# MonthlyRate                           19479
# NumCompaniesWorked                        8
# Over18                                    Y
# ...

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:
df.sort_index()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:
df.sort_values('Age')
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1839             18        No         Non-Travel       1431
# 614              18       Yes  Travel_Frequently       1306
# 1368             18        No         Non-Travel       1124
# 411              18        No      Travel_Rarely        812
# 405              18       Yes      Travel_Rarely        230
# ...             ...       ...                ...        ...
# 732              60        No      Travel_Rarely       1179
# 573              60        No  Travel_Frequently       1499
# 549              60        No      Travel_Rarely        422
# 1233             60        No      Travel_Rarely        696
# 1697             60        No      Travel_Rarely        370
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1839            Research & Development                14          3
# 614                              Sales                 5          3
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:
df.sample()
# Out:
#                 Age Attrition BusinessTravel  DailyRate Department  \
# EmployeeNumber
# 128              24        No  Travel_Rarely       1353      Sales
#
#                 DistanceFromHome  Education EducationField  EmployeeCount  \
# EmployeeNumber
# 128                            3          2          Other              1
#
#                 EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# EmployeeNumber                           ...
# 128                                   1  ...                        1
#
#                 StandardHours  StockOptionLevel  TotalWorkingYears  \
# EmployeeNumber
# 128                        80                 1                  4
#
#                TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# EmployeeNumber
# 128                                2                2              3
#
#                 YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 128                              2                        0
#
# ...

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A: No CEO in this dataset, find Research Director 
df[df['JobRole'] == 'Research Director']
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 28               34        No      Travel_Rarely        419
# 58               41       Yes      Travel_Rarely       1360
# 73               33        No  Travel_Frequently        515
# 80               50        No      Travel_Rarely        989
# 101              45        No      Travel_Rarely        193
# ...             ...       ...                ...        ...
# 1941             49        No  Travel_Frequently       1064
# 1979             31        No         Non-Travel        697
# 2000             47        No         Non-Travel       1162
# 2015             38        No      Travel_Rarely        201
# 2017             37        No      Travel_Rarely        161
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 28              Research & Development                 7          4
# 58              Research & Development                12          3
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:
df.groupby(['Age']).sum()
# Out:
#      DailyRate  DistanceFromHome  Education  EmployeeCount  \
# Age
# 18        5981                49         20              8
# 19        4936                95         19              9
# 20        9014                78         29             11
# 21        9917               118         21             13
# 22       12911               135         29             16
# 23        9911               128         26             14
# 24       22441               309         55             26
# 25       19970               228         50             26
# 26       32946               399        103             39
# 27       43552               360        128             48
# 28       44520               426        134             48
# 29       52993               735        175             68
# 30       47476               591        166             60
# 31       50037               639        211             69
# 32       46742               444        186             61
# ...

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
# A:
plt.hist(df.Age)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
plt.boxplot(df.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26acf2330a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26acf233520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26acf233d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x26acea7e160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26acea7e850>],
#  'means': []}

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
plt.scatter(df.Age, df.YearsAtCompany)
plt.xlabel('Age')
plt.ylabel('Years at company')
plt.show()

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A: store_name is not found in dataset, using department instead
plt.hist(df.Department, bins = 3)
plt.show()

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A:
from scipy import stats
print('statistical summary of observations =',stats.describe(df.Age))
# Out:
# statistical summary of observations = DescribeResult(nobs=1470, minmax=(18, 60), mean=36.923809523809524, variance=83.45504878602223, skewness=0.41286446154785084, kurtosis=-0.40685066033188644)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
